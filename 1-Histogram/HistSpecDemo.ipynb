# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %%
image_path = '.\\imgs\\Lenna.png'
img = cv2.imread(image_path)[..., ::-1] # Conevrt to RGB
hists = get_hist_multiple_channel(img)

channel_names = ['R', 'G', 'B']
img_name = 'Original image'
show_histogram(hists, img=img, channel_names=channel_names, img_name=img_name)

# %%
style_path = '.\\imgs\\style_paint.jpeg'
style = cv2.imread(style_path)[..., ::-1] # Conevrt to RGB
style_hists = get_hist_multiple_channel(style)

channel_names = ['R', 'G', 'B']
img_name = 'Style image'
show_histogram(style_hists, img=style, channel_names=channel_names, img_name=img_name)

# %%
_, new_img = specialize_hists(style_hists, hists, img)
new_hists = get_hist_multiple_channel(new_img)

channel_names = ['R', 'G', 'B']
img_name = 'Stylized image'
show_histogram(new_hists, img=new_img, channel_names=channel_names, img_name=img_name)

# %%
modified_img = exact_specialize_hists_multiple_channel(style_hists, new_img)
modified_img_raw = exact_specialize_hists_multiple_channel(style_hists, img)
modified_hist = get_hist_multiple_channel(modified_img)
modified_hist_raw = get_hist_multiple_channel(modified_img)

show_histogram(modified_hist, modified_img)
show_histogram(modified_hist_raw, modified_img_raw)
